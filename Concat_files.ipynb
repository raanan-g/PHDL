# %%
import pandas as pd

# %%
years = '99','00','01','02','03','04','05','06','07','08','09','10','11','12','13','14','15','16','17'

# %%
df = pd.read_csv("C:/Users/raana/OneDrive/Desktop/MOIRA/pa_lung99.csv")

# %%
for item in years:
    _df = pd.read_csv("C:/Users/raana/OneDrive/Desktop/MOIRA/pa_lung"+item+".csv")
    yr = []
    year = '20'+item
    for i in range(0,len(_df)):
        yr.append(year)
    _df['Year'] = yr 
    df = pd.concat([df,_df])
df
# Out:
#     Formatted_FIPS          County State      Deaths  Population  \
# 0            42001           Adams    PA          45       90363
# 1            42003       Allegheny    PA        1005     1287247
# 2            42005       Armstrong    PA          54       72572
# 3            42007          Beaver    PA         137      182592
# 4            42009         Bedford    PA          26       49853
# 5            42011           Berks    PA         210      370942
# 6            42013           Blair    PA          87      129757
# 7            42015        Bradford    PA          36       62701
# 8            42017           Bucks    PA         340      593947
# 9            42019          Butler    PA          89      172924
# 10           42021         Cambria    PA         111      153911
# 11           42023         Cameron    PA  SUPPRESSED        6026
# 12           42025          Carbon    PA          41       58845
# ...

# %%
df.to_csv("C:/Users/raana/OneDrive/Desktop/MOIRA/pa_lung_99_17.csv")
